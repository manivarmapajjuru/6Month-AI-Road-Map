# %%
pip install -q -U  google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# using gemini_api key to do the GENAI model the model is like the chart gpt when user give to input it generate the things what he wants

# %% [markdown]
# # Text Generative model using GeminiAI

# %%
import google.generativeai as genai

# Correct: use api_key (not apikey)
genai.configure(api_key='AIzaSyB5NbMVFrNYwXKTR5qXwZyS1MtUSM4G9u0')

# Correct model name
model=genai.GenerativeModel("gemini-2.5-flash-preview-04-17")

# Correct spelling of variable: response (not resonse)
response = model.generate_content("What is karma?")

# Print the response
print(response.text)
# Out:
# **Karma** is a fundamental concept originating in Indian religions, primarily Hinduism, Buddhism, Jainism, and Sikhism.
#
# At its core, it's the principle of **cause and effect** applied to actions and their consequences, particularly regarding moral and ethical conduct.
#
# Here's a breakdown of its key aspects:
#
# 1.  **Action and Consequence:** The word "karma" literally means "action," "deed," or "work" in Sanskrit. The principle states that every action (physical, mental, or verbal) creates an energy or force that will result in corresponding consequences (often called "phala," meaning "fruit" or "result"). Good actions lead to positive results, and negative actions lead to negative results.
#
# ...

# %% [markdown]
#  ### for getting the Gemini Lastest Techniques

# %%
for m in genai.list_models():
    print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# ...

# %% [markdown]
# ##### TO GET CLEAR TEXT

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('*', ' *')
    return Markdown(textwrap.indent(text, '> ', predicate = lambda _: True))

# %% [markdown]
# # Multimodel using Gemini_A
# #### PIL
# This line imports the Image class from the Pillow library (Python Imaging Library – PIL). It allows you to open, manipulate, and process images in Python.

# %% [markdown]
# | Use Case                       | Example                                          |
# | ------------------------------ | ------------------------------------------------ |
# | 🖼️ Open an image file         | `img = Image.open("photo.jpg")`                  |
# | 🔁 Convert image format        | `img = img.convert("RGB")`                       |
# | 📏 Resize an image             | `img = img.resize((300, 300))`                   |
# | 💾 Save an image               | `img.save("new_photo.png")`                      |
# | 🔍 Crop a region               | `cropped = img.crop((left, top, right, bottom))` |
# | 🖨️ Display an image (Jupyter) | `IPython.display.display(img)`                   |
# | 🧠 Pass image to Gemini        | Use `Image.open()` + Gemini multimodal input     |

# %% [markdown]
# ##### image to text GenAI
# ##### text to image
# ### but it doesn't support direct  generation of image using text but it will update future

# %% [markdown]
# ##### image to text

# %%
import PIL.Image 
img=PIL.Image.open(r"C:\Users\hp\OneDrive\Pictures\mb1.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x442>

# %%
import google.generativeai as genai
import PIL.Image
from IPython.display import Markdown
import textwrap

# Configure the API
genai.configure(api_key='AIzaSyAlBlhxPS5hTfCeVHNC6ZK03LcEjegN2cs')

model=genai.GenerativeModel("gemini-2.5-flash-preview-04-17")
# Load the image
img = PIL.Image.open(r"C:\Users\hp\OneDrive\Pictures\mb1.jpg")

response=model.generate_content([img,"describe ABOUT Him"])# image to text
to_markdown(response.text)
# Out:
# > Based on the image, here is a description of the man:
# >
# > The man has dark, wavy hair and short facial stubble. He is looking upwards and slightly to his left, with a wide, genuine smile on his face, showing his teeth. His expression appears happy and engaged. He is wearing a simple, light blue short-sleeved t-shirt with a small logo on the left chest. His hands are clasped in front of him. The lighting creates highlights on his face, especially his forehead and cheek, and there seems to be some colored light reflecting on him. The background is dark and blurry, suggesting he is indoors, possibly at an event.

# %% [markdown]
# # Text to Image

# %%
img = PIL.Image.open(r"C:\Users\hp\OneDrive\Pictures\mb1.jpg")
response=model.generate_content(["describe about him",img]) # text to image
to_markdown(response.text)
# Out:
# > The image shows a man with brown hair and a beard, smiling and looking upwards. He is wearing a light blue t-shirt. The lighting highlights his face, particularly his smile. He appears to be enjoying something off-camera, with a happy and relaxed expression.
